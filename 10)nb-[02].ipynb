# %%
# balls -> shuffle

for i in range(0, 1000000):
    temp = balls[0]
    r_num = int(random.random() * len(balls)) # 0-44
    #r_num = math.floor(random.damdom() * len(balls))
    balls[0] = balls[r_num]
    balls[r_num] = temp

print(balls)
print(balls[:6])

# %%
# ramdom 모듈 안에 sample() 함수 사용

print(ramdom.sample(range(1, 46), 6))

lotto = ramdom.sample(range(1, 46), 6)
print(lotto)
lotto.sort()
print(lotto)

# %%
for i in range(10):
    lotto = ramdom.smaple(range(1, 46), 6)
    lotto.sort()
    print(f'{i}번 째 로또 번호: {lotto}')

# %%
def my_lotto_create(a):
    result = []
    for i in range(a):
        lotto = random.sample(range(1, 46), 6)
        lotto.sort()
        #print(f'{i+1}번째 로또 번호: {lotto}')
        result.append(tuple(lotto))
    return tuple(result)

# %%
result = my_lotto_create(10)
print(result)

# %%
def dice_cast():
    d1 = random.randint(1,6)
    d2 = random.randint(1,6)
    return d1 + d2

# person1_dice = {'name': '홍길동', 'dice_value': 0};
# person1_dice['dice_value'] = dice_cast()

person1_dice = dice_cast();
person2_dice = dice_cast();

if person1_dice == person2_dice:
    print(f'비겼다. person1:{person1_dice}, person2:{person2_dice}')
elif person1_dice> person2_dice:
    print(f'person1_dice Win. person1:{person1_dice}, person2:{person2_dice}')
else:
    print(f'person2_dice Win. person1:{person1_dice}, person2:{person2_dice}')
