# %%
import pandas as pd

df = pd.read_csv('9-4)_work_V2.csv')

df['평균'] = (df['국어'] + df['영어']) / 2

sorted_df = df.sort_values('평균', ascending=False)

top_df = sorted_df[sorted_df['평균'] >= 90]

print(sorted_df)
print(top_df)
# Out:
#      이름   국어   영어    평균
# 4   유관순  100   98  99.0
# 2   김유신   95  100  97.5
# 9  세종대왕   93   94  93.5
# 7  신사임당   92   95  93.5
# 6   윤봉길   91   92  91.5
# 1   이순신   88   90  89.0
# 8   장보고   87   89  88.0
# 0   홍길동   90   85  87.5
# 5   안중근   85   88  86.5
# 3   강감찬   82   84  83.0
#      이름   국어   영어    평균
# 4   유관순  100   98  99.0
# 2   김유신   95  100  97.5
# 9  세종대왕   93   94  93.5
# 7  신사임당   92   95  93.5
# 6   윤봉길   91   92  91.5
