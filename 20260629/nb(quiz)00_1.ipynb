# %%
# 결측치(missing value)는 말 그대로 값이 비어 있거나 존재하지 않는 데이터
# Out:
# 10

# %%
orders = [
    {"주문번호": 1001, "고객명": "김철수", "구매금액": 120000, "가입일": "2021-03-15", "지역": "서울"},
    {"주문번호": 1002, "고객명": "이영희", "구매금액": None, "가입일": "2020-08-10", "지역": "부산"},
    {"주문번호": 1003, "고객명": "박민수", "구매금액": 35000, "가입일": "2024-01-20", "지역": "서울"},
    {"주문번호": 1004, "고객명": "최지은", "구매금액": -5000, "가입일": "2019-05-12", "지역": "대구"},
    {"주문번호": 1005, "고객명": "정우성", "구매금액": 550000, "가입일": "2018-11-02", "지역": "서울"},
    {"주문번호": 1006, "고객명": "한지민", "구매금액": None, "가입일": "2022-07-01", "지역": "부산"},
    {"주문번호": 1007, "고객명": "강호동", "구매금액": 25000, "가입일": "2023-09-15", "지역": "광주"},
    {"주문번호": 1008, "고객명": "신세경", "구매금액": 9999999, "가입일": "2021-12-24", "지역": "서울"},
    {"주문번호": 1009, "고객명": "유재석", "구매금액": 89000, "가입일": "2020-01-05", "지역": "대전"},
    {"주문번호": 1010, "고객명": "송혜교", "구매금액": 175000, "가입일": "2017-04-30", "지역": "서울"},
]

len(orders)
# Out:
# 10

# %%
# 문제1) 결측치 확인: 구매금액이 결측치(None)인 데이터의 개수를 구하시오.

missing_count = 0

for orders in orders:
    if orders["구매금액"] is None:
        missing_count += 1

print("결측치 개수:", missing_count)
# Out:
# 결측치 개수: 2

# %%
# 문제2) 결측치 처리: 결측치를 제외한 구매금액 평균을 계산한 후 결측치를 평균값으로 대체하시오.

#구매금액 = []

#for 구매금액 in 구매금액:
#    if orders["구매금액"] is not None:
#        구매금액.append(orders["구매금액"])


#avg = sum(구매금액) / len(구매금액)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 10
#       6     if orders["구매금액"] is not None:
#       7         구매금액.append(orders["구매금액"])
#       8
#       9
# ---> 10 avg = sum(구매금액) / len(구매금액)
#
# ZeroDivisionError: division by zero

# %%
# 오답 풀이

구매금액_list = []

for orders in orders:
    if order["구매금액"] is not None:
        구매금액_list.append(order["구매금액"])

avg = sum(구매금액_list) / len(구매금액_list)

# %%
# 문제 3. 이상치 탐지: 구매금액이 (0 ~ 1,000,000원) 범위를 벗어나면 이상치로 판단한다.

# %%
# 문제 4. 이상치 처리: 이상치는 다음 기준으로 수정하시오.

#1,000,000 초과 → 1,000,000
#0 미만 → 0

# %%
#문제 5. 회원 가입 연수 계산 (특성 추출)
#: 현재 연도를 기준으로 회원 가입 후 몇 년이 지났는지 계산하여 "가입연수" 컬럼을 추가하시오.

# %%
#문제6) VIP 여부 생성 (특성 추출)

# 구매금액 기준
# 200000원 이상 → VIP
# 200000원 미만 → 일반
# 으로 "회원등급" 컬럼을 추가하시오.

# 예시)
# {
#     ...
#     '회원등급':'VIP'
# }

# %%
# 문제 7. 기술통계
# 구매금액에 대한 [개수, 합계, 합계, 최대값, 최소값]
#을 출력하시오.

# %%
#문제 8. 지역별 평균 구매금액
# 지역별 평균 구매금액을 구하시오.

# %%
# 문제 9. 회원등급별 평균 구매금액
# VIP 회원과 일반 회원의 평균 구매금액을 구하시오.

# %%
# 문제 10. 가입연수별 그룹 분석
# 가입연수를 기준으로 다음과 같이 그룹을 나누시오.

# 0~2년
# 3~5년
# 6년 이상

# 각 그룹의 평균 구매금액을 구하시오.

# %%
# 심화 문제 (딕셔너리, 리스트, 반복문, 조건문을 모두 활용)

# 문제 11. 가장 구매금액이 높은 고객 TOP 3를 출력하시오.

# %%
# 문제 12. 지역별 고객 수를 구하시오.

# %%
# 문제 13. VIP 회원 비율을 구하시오.
