# %%
import csv

with open('score.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    data = list(reader)

print(data)
# Out:
# [{'이름': '홍길동', '나이': '20', '국어': '90', '영어': '85'}, {'이름': '이순신', '나이': '21', '국어': '88', '영어': '90'}, {'이름': '김유신', '나이': '', '국어': '95', '영어': '100'}, {'이름': '강감찬', '나이': '22', '국어': '결측', '영어': '82'}, {'이름': '유관순', '나이': '19', '국어': '100', '영어': '110'}, {'이름': '안중근', '나이': '150', '국어': '85', '영어': '88'}, {'이름': '윤봉길', '나이': '20', '국어': '-5', '영어': '91'}, {'이름': '신사임당', '나이': '21', '국어': '92', '영어': ''}, {'이름': '장보고', '나이': '18', '국어': '87', '영어': '89'}, {'이름': '세종대왕', '나이': '23', '국어': '93', '영어': '94'}, {'이름': '을지문덕', '나이': '20', '국어': '91', '영어': '86'}, {'이름': '허준', '나이': '21', '국어': '89', '영어': '87'}, {'이름': '김구', '나이': '22', '국어': '500', '영어': '92'}, {'이름': '이황', '나이': '19', '국어': '84', '영어': '81'}, {'이름': '이이', '나이': '20', '국어': '86', '영어': 'NaN'}, {'이름': '정약용', '나이': '21', '국어': '90', '영어': '88'}, {'이름': '논개', '나이': '22', '국어': '88', '영어': '85'}, {'이름': '계백', '나이': '20', '국어': '', '영어': '84'}, {'이름': '관우', '나이': '19', '국어': '97', '영어': '96'}, {'이름': '장비', '나이': '20', '국어': '
# ...

# %%
name = '홍길동'
age = '20'
korean = '90'
english = '85'

students = {}
students[korean] = int(score)
students[english] = int(score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       3 korean = '90'
#       4 english = '85'
#       5
#       6 students = {}
# ----> 7 students[korean] = int(score)
#       8 students[english] = int(score)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'
