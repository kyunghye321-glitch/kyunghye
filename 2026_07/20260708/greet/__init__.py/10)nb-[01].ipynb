# %%
# greet 패키지
# greet / ko.py - ko greet(), en.py - en_greet()

import greet

greet.ko.ko_greet('홍길동')
greet.en.en_greet('홍길동')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 6
#       2 # greet / ko.py - ko greet(), en.py - en_greet()
#       3
#       4 import greet
#       5
# ----> 6 greet.ko.ko_greet('홍길동')
#       7 greet.en.en_greet('홍길동')
#
# AttributeError: module 'greet' has no attribute 'ko'

# %%
from greet
